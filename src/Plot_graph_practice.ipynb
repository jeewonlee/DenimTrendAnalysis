# %%
import pickle
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mat = pickle.load(open("../../picklefiles/nmf_v10.pkl", "rb"))

# %%
df = pd.read_csv('../../data/cleandata/all_v3.csv', delimiter=';')
if len(df.columns)==6:
    df.columns = [u'date', u'text', u'geo', u'mentions', u'hashtags', u'Unnamed: 5']
elif len(df.columns)==7:
    df.columns = [u'date', u'text', u'geo', u'mentions', u'hashtags', u'Unnamed: 5','yo']
else:
    print 'too many columns', len(df.columns)
print "length of dataframe",len(df)
# Out:
# too many columns 12
# length of dataframe 813398

# %%
df['date'] = df.date.apply(datetime.datetime.strptime, args=('%Y-%m-%d',))
dates = df['date']
mat_df = pd.DataFrame(mat)
mat_df['date']=dates

# %%
groupdate = mat_df.groupby([mat_df.date.dt.year, mat_df.date.dt.month]).sum()
groupdate.index.names=['year','month']
groupdate.drop(groupdate.index[0:4], inplace=True)
date_counts = mat_df.groupby([mat_df.date.dt.year, mat_df.date.dt.month]).count()
date_counts.index.names=['year','month']
date_counts.drop(date_counts.index[0:4], inplace=True)
new = groupdate/date_counts
del new['date']

# %%
del topics

# %%
topics=['???','Fit Jeans','Skinny Jeans','Blue Jeans','Ripped Jeans','Black Jeans','White Jeans','Tight Jeans','High Waisted Jeans','Boyfriend Jeans']

# %%
len(topics)
# Out:
# 30

# %%
topics.extend(['Leggings','Jeans+Shirts','Cannot fit jeans','Mom Jeans','Shorts vs Jeans?','Yoga Pants','Boot cut Jeans','Luke Hemmings','Hate Jeans - unconfortable','America Eagle'])

# %%
topics.extend(['Have not wear jeans for long','Jeans+Butt','Blue jeans + white shirt','True religion','jeans for that back','Hate Jeans','Jeans+Boots','Need Shoes&Jeans','Girls+Jeans','Rip Jeans?'])

# %%
new.columns=topics

# %%
temp = new.copy()

# %%
temp['year']= temp.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-85fd894141c1> in <module>()
# ----> 1 temp['year']= temp.index
#
# NameError: name 'temp' is not defined

# %%
date_list=temp['year']

# %%
index_graph=["2013 Winter","2013 Spring",'2013 Summer', '2013 Fall',"2014 Winter","2014 Spring",'2014 Summer', '2014 Fall','2015 Winter', "2015 Spring",'2015 Summer', '2015 Fall','2016 Winter', "2016 Spring",'2016 Summer', '2016 Fall']

# %%
ax = new.iloc[:,0].plot()
ax.set_xlabel('Time Periode')
ax.set_ylabel('Frequency Ratio')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
ax.set_xticklabels(index_graph, rotation=90)
ax.set_xticks(np.arange(0,47,3))
ax.axvline(x=12, color='k', linestyle='solid')
ax.axvline(x=24, color='k', linestyle='solid')
ax.axvline(x=36, color='k', linestyle='solid')
#ax.axvline(x=12, color='r', linestyle='solid')
#plt.figure(figsize=(30,30))
plt.legend(fontsize = 'x-small', bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
ax = new.iloc[:,1:5].plot()
ax.set_xlabel('Time Periode')
ax.set_ylabel('Frequnecy Ratio')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
ax.set_xticklabels(index_graph, rotation=90)
ax.set_xticks(np.arange(0,47,3))
ax.axvline(x=12, color='k', linestyle='solid')
ax.axvline(x=24, color='k', linestyle='solid')
ax.axvline(x=36, color='k', linestyle='solid')
#ax.set_xticks(np.arange(len(new.index)))
#plt.figure(figsize=(30,30))
plt.legend(fontsize = 'x-small', bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
ax = new.iloc[:,5:10].plot()
ax.set_xlabel('Time Periode')
ax.set_ylabel('Frequnecy Ratio')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
ax.set_xticklabels(index_graph, rotation=90)
ax.set_xticks(np.arange(0,47,3))
ax.axvline(x=12, color='k', linestyle='solid')
ax.axvline(x=24, color='k', linestyle='solid')
ax.axvline(x=36, color='k', linestyle='solid')
#ax.set_xticks(np.arange(len(new.index)))
#plt.figure(figsize=(30,30))
plt.legend(fontsize = 'x-small', bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
ax = new.iloc[:,10:15].plot()
ax.set_xlabel('Time Periode')
ax.set_ylabel('Frequnecy Ratio')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
ax.set_xticklabels(index_graph, rotation=90)
ax.set_xticks(np.arange(0,47,3))
ax.axvline(x=12, color='k', linestyle='solid')
ax.axvline(x=24, color='k', linestyle='solid')
ax.axvline(x=36, color='k', linestyle='solid')
#ax.set_xticks(np.arange(len(new.index)))
#plt.figure(figsize=(30,30))
plt.legend(fontsize = 'x-small', bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
ax = new.iloc[:,15:20].plot()
ax.set_xlabel('Time Periode')
ax.set_ylabel('Frequnecy Ratio')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
ax.set_xticklabels(index_graph, rotation=90)
ax.set_xticks(np.arange(0,47,3))
ax.axvline(x=12, color='k', linestyle='solid')
ax.axvline(x=24, color='k', linestyle='solid')
ax.axvline(x=36, color='k', linestyle='solid')
#ax.set_xticks(np.arange(len(new.index)))
#plt.figure(figsize=(30,30))
plt.legend(fontsize = 'x-small', bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
ax = new.iloc[:,20:25].plot()
ax.set_xlabel('Time Periode')
ax.set_ylabel('Frequnecy Ratio')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
ax.set_xticklabels(index_graph, rotation=90)
ax.set_xticks(np.arange(0,47,3))
ax.axvline(x=12, color='k', linestyle='solid')
ax.axvline(x=24, color='k', linestyle='solid')
ax.axvline(x=36, color='k', linestyle='solid')
#ax.set_xticks(np.arange(len(new.index)))
#plt.figure(figsize=(30,30))
plt.legend(fontsize = 'x-small', bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
ax = new.iloc[:,25:30].plot()
ax.set_xlabel('Time Period')
ax.set_ylabel('Frequnecy Ratio')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
ax.set_xticklabels(index_graph, rotation=90)
ax.set_xticks(np.arange(0,47,3))
ax.axvline(x=12, color='k', linestyle='solid')
ax.axvline(x=24, color='k', linestyle='solid')
ax.axvline(x=36, color='k', linestyle='solid')
#ax.set_xticks(np.arange(len(new.index)))
#plt.figure(figsize=(30,30))
plt.legend(fontsize = 'x-small', bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
ax = new.iloc[:,[2,4]].plot(color=['b','g'])
ax.set_xlabel('Time Period')
ax.set_ylabel('Frequency Ratio')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
ax.set_xticklabels(index_graph, rotation=90)
ax.set_xticks(np.arange(0,47,3))
ax.axvline(x=12, color='k', linestyle='solid')
ax.axvline(x=24, color='k', linestyle='solid')
ax.axvline(x=36, color='k', linestyle='solid')
#ax.set_xticks(np.arange(len(new.index)))
#plt.figure(figsize=(30,30))
plt.legend(bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
ax = new.iloc[:,[5,6]].plot(color=['c','m'])
ax.set_xlabel('Time Period')
ax.set_ylabel('Frequency Ratio')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
ax.set_xticklabels(index_graph, rotation=90)
ax.set_xticks(np.arange(0,47,3))
ax.axvline(x=12, color='k', linestyle='solid')
ax.axvline(x=24, color='k', linestyle='solid')
ax.axvline(x=36, color='k', linestyle='solid')
#ax.set_xticks(np.arange(len(new.index)))
#plt.figure(figsize=(30,30))
plt.legend(bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
ax = new.iloc[:,[8,9]].plot(color=['r','g'])
ax.set_xlabel('Time Period')
ax.set_ylabel('Frequnecy Ratio')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
ax.set_xticklabels(index_graph, rotation=90)
ax.set_xticks(np.arange(0,47,3))
ax.axvline(x=12, color='k', linestyle='solid')
ax.axvline(x=24, color='k', linestyle='solid')
ax.axvline(x=36, color='k', linestyle='solid')
#ax.set_xticks(np.arange(len(new.index)))
#plt.figure(figsize=(30,30))
plt.legend(bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
ax = new.iloc[:,[10,16]].plot(color=['b','g'])
ax.set_xlabel('Time Period')
ax.set_ylabel('Frequnecy Ratio')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
ax.set_xticklabels(index_graph, rotation=90)
ax.set_xticks(np.arange(0,47,3))
ax.axvline(x=12, color='k', linestyle='solid')
ax.axvline(x=24, color='k', linestyle='solid')
ax.axvline(x=36, color='k', linestyle='solid')
#ax.set_xticks(np.arange(len(new.index)))
#plt.figure(figsize=(30,30))
plt.legend(bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
ax = new.iloc[:,[13,14]].plot(color=['c','m'])
ax.set_xlabel('Time Period')
ax.set_ylabel('Frequnecy Ratio')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
ax.set_xticklabels(index_graph, rotation=90)
ax.set_xticks(np.arange(0,47,3))
ax.axvline(x=12, color='k', linestyle='solid')
ax.axvline(x=24, color='k', linestyle='solid')
ax.axvline(x=36, color='k', linestyle='solid')
#ax.set_xticks(np.arange(len(new.index)))
#plt.figure(figsize=(30,30))
plt.legend(bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
ax = new.iloc[:,[0,17]].plot(color=['r','g'])
ax.set_xlabel('Time Period')
ax.set_ylabel('Frequnecy Ratio')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
ax.set_xticklabels(index_graph, rotation=90)
ax.set_xticks(np.arange(0,47,3))
ax.axvline(x=12, color='k', linestyle='solid')
ax.axvline(x=24, color='k', linestyle='solid')
ax.axvline(x=36, color='k', linestyle='solid')
#ax.set_xticks(np.arange(len(new.index)))
#plt.figure(figsize=(30,30))
plt.legend(bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')
