# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.plotly as py
import plotly.graph_objs as go

# %%
df = pd.read_csv('../../data/Shopstyle/jeans_data.csv')
df.rename(columns={" brand_name":"brand_name"})
#most = df['brand_name'].value_counts().head(10).to_frame()
# Out:
#        popular_id location  product_id currency   price  retailer_id  \
# 0               1    en_US   452533837      USD  199.00            1
# 1               2    en_US   505660976      USD   70.00            1
# 2               3    en_US   448332941      USD  228.00            1
# 3               4    en_US   536292494      USD   34.94           61
# 4               5    en_US   486763868      USD  265.00            9
# 5               6    en_US   512062252      USD  148.00           21
# 6               7    en_US   516268185      USD  199.00            7
# 7               8    en_US   505662260      USD  195.00            1
# 8               9    en_US   488193590      USD  168.00            1
# 9              10    en_US   531843408      USD   88.00          992
# 10             11    en_US   537018369      USD  125.00            5
# 11             12    en_US   466942970      USD  225.00           21
# 12             13    en_US   534607603      USD  218.00         2354
# 13             14    en_US   540141437      USD   98.00           21
# 14             15    en_US   511943498      USD   88.00           21
# 15             16    en_US   453504852      USD   79.00           29
# 16             17    en_US   603509252      USD  189.00            1
# 17             18    en_US   511943821      USD  158.00           21
# 18             19    en_US   455788451      USD  115.00            5
# 19             20    en_US   480491878      USD   19.99         1689
# 20             21    en_US   490964517      USD  199.00            7
# 21             22    en_US   532546371      USD   89.00           53
# 22             23    en_US   534889087      USD   39.00            1
# 23             24    en_US   513937105      USD   75.00            1
# 24             25    en_US   603103055      USD  215.00            6
# 25             26    en_US   537240068      USD   69.99         1689
# 26             27    en_US   536763357      USD   88.00            1
# 27             28    en_US   490972702      USD  218.00            7
# 28             29    en_US   534952171      USD   88.00           21
# 29             30    en_US   505640663      USD   64.00           29
# ...           ...      ...         ...      ...     ...          ...
# 74370       74371    en_US   537581069      USD  198.00          920
# 74371       74372    en_US   535811577      USD  199.00          920
# 74372       74373    en_US   601536489      USD   82.00         1839
# 74373       74374    en_US   482968042      USD  135.00           25
# 74374       74375    en_US   454109987      USD   79.00          457
# 74375       74376    en_US   497770593      USD   29.94           61
# 74376       74377    en_US   533016676      USD   44.94           61
# 74377       74378    en_US   473733179      USD  165.00           25
# 74378       74379    en_US   496156072      USD  351.00           25
# 74379       74380    en_US   602774573      USD  764.00           25
# 74380       74381    en_US   482452030      USD  178.00            8
# 74381       74382    en_US   530566139      USD  234.00           25
# 74382       74383    en_US   532091312      USD  199.00           25
# 74383       74384    en_US   523887638      USD  232.00           25
# 74384       74385    en_US   510582518      USD  203.00           25
# 74385       74386    en_US   604311207      USD  179.00         2003
# 74386       74387    en_US   521751775      USD  200.00           25
# 74387       74388    en_US   535375961      USD  199.00          421
# 74388       74389    en_US   600805102      USD  359.00          421
# 74389       74390    en_US   522355589      USD  280.00            9
# 74390       74391    en_US   600469205      USD   78.00         1378
# 74391       74392    en_US   533271541      USD  148.00          717
# 74392       74393    en_US   485320093      USD   29.99         1689
# 74393       74394    en_US   536733692      USD   88.00           22
# 74394       74395    en_US   539468231      USD  168.00           22
# 74395       74396    en_US   537786319      USD  198.00          720
# 74396       74397    en_US   490972828      USD  158.00            7
# 74397       74398    en_US   521754036      USD  258.00            7
# 74398       74399    en_US   602931604      USD   98.00         1542
# 74399       74400    en_US   474400352      USD  138.00            6
#
#            retailer_name   brand_id            brand_name  \
# 0              Nordstrom      33198                 Frame
# 14     Raw holes and heavy fading lend a favorite-pai...   2016-02-22
# 15     5pocket ripped skinny jean cut in a relaxed sl...   2014-06-18
# 16     Crafted with a gap-proof contoured waistband a...   2016-10-21
# 17     Heavy fading and shredded holes lend a well-wo...   2016-02-22
# 18     Our toothpick skinny + a higher rise = a nippe...   2014-07-22
# 19     Pants in washed superstretch twill with a high...   2015-06-04
# 20     Second-skin jeans with a dose of punk edge tha...   2015-09-10
# 21     The Cameron boasts a semi-relaxed fit and a st...   2016-07-14
# 22     Stitched knee panels add a cool moto vibe to p...   2016-08-01
# 23     High-waisted skinny jeans in a versatile mediu...   2016-03-08
# 24     rag & bone/JEAN "401" jeans in Joshua wash. Fi...   2016-10-18
# 25     Shaping. 5-pocket jeans in washed denim with t...   2016-08-17
# 26     Comfortable skinny jeans with a hint of stretc...   2016-08-13
# 27     Punk-chic tears and raw-edged cuffs are kept p...   2015-09-10
# 28     Whiskered creases and a raw hem lend a natural...   2016-08-01
# 29     Our classic skinny twig jean in a modern indig...   2016-01-08
# ...                                                  ...          ...
# 74370  Sleek stylish and colorful! ; The Margaux ankl...   2016-08-16
# 74371  Seriously slimming skinnies from the 7 For All...   2016-08-05
# 74372  <ul><li>Zip fly button closure belt loops faux...   2016-10-11
# 74373  LEVI&apos;S&reg; MADE & CRAFTED&trade; Jeans. ...   2015-06-28
# 74374  The jegging version of our customer favorite j...   2014-06-28
# 74375  <ul> <li>2% spandex 20% polyester 78% cotton.<...   2015-11-05
# 74376  <ul> <li>1% Lycra 12% Polyester 87% Cotton.</l...   2016-07-18
# 74377  LIU JO JEANS Casual pants. low waisted belt lo...   2015-03-15
# 74378  DSQUARED2 Jeans. denim solid color worn effect...   2015-10-24
# 74379  BALMAIN Jeans. denim solid color faded effect ...   2016-01-15
# 74380  Eileen Fisher Skinny Jeans in Washed Indigo <u...   2015-06-23
# 74381  CITIZENS OF HUMANITY Jeans. denim solid color ...   2016-01-15
# 74382  CITIZENS OF HUMANITY Jeans. denim basic solid ...   2016-01-15
# 74383  MOTHER Jeans. denim solid color mid rise color...   2016-01-15
# 74384  ACNE STUDIOS Jeans. denim solid color mid rise...   2016-02-10
# 74385  Part of Joe's Collector's Edition The #Hello B...   2016-10-25
# 74386  KSUBI Jeans. denim solid color mid rise dark w...   2016-01-15
# 74387  Our Cora Mid Rise Straight Crop is a perfect p...   2016-08-04
# 74388  The Audrey Mid Rise Boyfriend features a sligh...   2016-10-08
# 74389  RE/DONE cotton denim Black High Rise Ankle Cro...   2016-05-05
# 74390  Vintage wash dark grey skinny jeans has destro...   2016-10-07
# 74391  Made in LA with high-quality locally sourced f...   2016-07-20
# 74392  5-pocket bootcut pants in washed superstretch ...   2015-07-23
# 74393  A curve-hugging skinny corduroy pair for easin...   2016-08-12
# 74394  Our ever-so-slightly boyish fit with a lived-i...   2016-08-31
# 74395  Limited edition and small batch Rivet & Thread...   2016-08-21
# 74396  Sleek ankle-length skinnies with plenty of str...   2015-09-10
# 74397  Stylish stiletto jeans accentuated with star p...   2016-01-15
# 74398  A subtle tartan plaid pattern is a must-have f...   2016-10-17
# 74399  True Religion Charlize jeans in faded whiskere...   2015-03-23
#
# [74400 rows x 12 columns]

# %%
def most_distributed(df):
#     df.rename(columns={' brand_name':'brand_name'})
    most = df['brand_name'].value_counts().head(10).to_frame()
    labels = most.index
    values = most.brand_name
    trace=go.Pie(labels=labels,values=values)
    py.iplot([trace])

# %%
most_distributed(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-55baf81b3210> in <module>()
# ----> 1 most_distributed(df)
#
# <ipython-input-43-2834d89f7029> in most_distributed(df)
#       1 def most_distributed(df):
#       2     df.rename(columns={' brand_name':'brand_name'})
# ----> 3     most = df['brand_name'].value_counts().head(10).to_frame()
#       4     labels = most.index
#       5     values = most.brand_name
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'brand_name'

# %%
most
# Out:
#                        brand_name
# Citizens of Humanity         4437
# J Brand                      3726
# Frame                        3039
# Rag & Bone                   2832
# Mother                       2611
# Paige                        2274
# AG Jeans                     2141
# Levi's                       2123
# Style&Co.                    1855
# H&M                          1718

# %%
df[' brand_name']
# Out:
# 0                       Frame
# 1                     Topshop
# 2             Current/Elliott
# 3                    Old Navy
# 4                     RE/DONE
# 5                      Levi's
# 6                       Frame
# 7                  Rag & Bone
# 8        Citizens of Humanity
# 9                      Levi's
# 10                     J.Crew
# 11                        3x1
# 12                     Mother
# 13                     Levi's
# 14                     Levi's
# 15                        BDG
# 16              Good American
# 17                     Levi's
# 18                     J.Crew
# 19                        H&M
# 20                      Paige
# 21         KUT from the Kloth
# 22                         BP
# 23                    Topshop
# 24                 Rag & Bone
# 25                        H&M
# 26                  Blank NYC
# 27                    J Brand
# 28                     Levi's
# 29                        BDG
#                  ...
# 74370                  DL1961
# 74371       7 For All Mankind
# 74372                  Dittos
# 74373                  Levi's
# 74374                 Athleta
# 74375                Old Navy
# 74376                Old Navy
# 74377                  Liu Jo
# 74378               DSQUARED2
# 74379                 Balmain
# 74380           Eileen Fisher
# 74381    Citizens of Humanity
# 74382    Citizens of Humanity
# 74383                  Mother
# 74384            Acne Studios
# 74385            Acne Studios
# 74386                   Ksubi
# 74387           True Religion
# 74388           True Religion
# 74389                 RE/DONE
# 74390           Flying Monkey
# 74391         Rebecca Minkoff
# 74392                     H&M
# 74393                     H&M
# 74394                     H&M
# 74395                Madewell
# 74396                 J Brand
# 74397         Current/Elliott
# 74398                    NYDJ
# 74399           True Religion
# Name:  brand_name, dtype: object
