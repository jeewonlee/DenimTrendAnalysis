# %%
import pickle
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mat = pickle.load(open("../../picklefiles/nmf_V2.pkl", "rb"))

# %%
df = pd.read_csv('../../data/twitter/all.csv', delimiter=';')
if len(df.columns)==6:
    df.columns = [u'date', u'text', u'geo', u'mentions', u'hashtags', u'Unnamed: 5']
elif len(df.columns)==7:
    df.columns = [u'date', u'text', u'geo', u'mentions', u'hashtags', u'Unnamed: 5','yo']
else:
    print 'too many columns', len(df.columns)
print "length of dataframe",len(df)
# Out:
# too many columns 9
# length of dataframe 842130

# %%
df['date'] = df.date.apply(datetime.datetime.strptime, args=('%Y-%m-%d',))
dates = df['date']
mat_df = pd.DataFrame(mat)
mat_df['date']=dates

# %%
groupdate = mat_df.groupby([mat_df.date.dt.year, mat_df.date.dt.month]).sum()
groupdate.index.names=['year','month']
groupdate.drop(groupdate.index[0:4], inplace=True)

# %%
date_counts = mat_df.groupby([mat_df.date.dt.year, mat_df.date.dt.month]).count()
date_counts.index.names=['year','month']
date_counts.drop(date_counts.index[0:4], inplace=True)

# %%
new = groupdate/date_counts
del new['date']

# %%
del topics

# %%
topics=['Ginuwine in those jeans','Ripped Jean','Lana Del Rey, Blue jean','Levis','Fit jeans','Skinny Jeans','Tight jeans','White Jeans - James Dean','Apple Bottom Jeans','Black Jeans','Ripped Pocket Jeans - Luke Hemmings']

# %%
topics.extend(['High waisted','White Jeans','Boyfriend Jeans','Leggings','Mom jeans','Slim fit jeans', 'Shorts, Basketball','??',
               'Painted tight jeans'])

# %%
topics.extend(['Boot cut','Luke Hemmings','Yoga Pants','balmain','Shirts','Long sleeve','American Eagle,hollister','Butt crack','True Religion','??'])

# %%
topics.extend(['Skin tight','??','Audrey Toner Becca Jeans-Pitchperfect','Cowboy Boots, fur','Running shoes','Tight Jeans','crease','rip jean','cute jean','baggy jeans','man fat jean'])

# %%
topics.extend(['Sweats jeans','Hollister-abercrombie','Dress Jeans','Old Navy','Summer jeans-shorts','Ripped Jeans','Blake Shelton-blue jean','Robin Jeans, Jimmy choo','Shirts'])

# %%
new.columns=topics

# %%
topics[41]
# Out:
# 'Sweats jeans'

# %%
ax = new.iloc[:,:5].plot()
ax.set_xlabel('Time Periode')
ax.set_ylabel('yay')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
#ax.x_ticklabels(new.)
#plt.figure(figsize=(30,30))
plt.legend(fontsize = 'x-small', bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
ax = new.iloc[:,5:10].plot()
ax.set_xlabel('Time Periode')
ax.set_ylabel('yay')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
#ax.x_ticklabels(new.)
#plt.figure(figsize=(30,30))
plt.legend(fontsize = 'x-small', bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
ax = new.iloc[:,10:15].plot()
ax.set_xlabel('Time Periode')
ax.set_ylabel('yay')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
#ax.x_ticklabels(new.)
#plt.figure(figsize=(30,30))
plt.legend(fontsize = 'x-small', bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
ax = new.iloc[:,15:20].plot()
ax.set_xlabel('Time Periode')
ax.set_ylabel('yay')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
#ax.x_ticklabels(new.)
#plt.figure(figsize=(30,30))
plt.legend(fontsize = 'x-small', bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
ax = new.iloc[:,20:25].plot()
ax.set_xlabel('Time Periode')
ax.set_ylabel('yay')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
#ax.x_ticklabels(new.)
#plt.figure(figsize=(30,30))
plt.legend(fontsize = 'x-small', bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
ax = new.iloc[:,25:30].plot()
ax.set_xlabel('Time Periode')
ax.set_ylabel('yay')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
#ax.x_ticklabels(new.)
#plt.figure(figsize=(30,30))
plt.legend(fontsize = 'x-small', bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
x = new.iloc[:,30:35].plot()
ax.set_xlabel('Time Periode')
ax.set_ylabel('yay')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
#ax.x_ticklabels(new.)
#plt.figure(figsize=(30,30))
plt.legend(fontsize = 'x-small', bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
x = new.iloc[:,35:40].plot()
ax.set_xlabel('Time Periode')
ax.set_ylabel('yay')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
#ax.x_ticklabels(new.)
#plt.figure(figsize=(30,30))
plt.legend(fontsize = 'x-small', bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
x = new.iloc[:,40:45].plot()
ax.set_xlabel('Time Periode')
ax.set_ylabel('yay')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
#ax.x_ticklabels(new.)
#plt.figure(figsize=(30,30))
plt.legend(fontsize = 'x-small', bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')

# %%
x = new.iloc[:,45:50].plot()
ax.set_xlabel('Time Periode')
ax.set_ylabel('yay')
ax.set_title('Denim Trend from 2012/12 to 2016/10')
#ax.x_ticklabels(new.)
#plt.figure(figsize=(30,30))
plt.legend(fontsize = 'x-small', bbox_to_anchor=(-0.2, 1.0))
#plt.legend(loc='upper right')
